# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fc783629-94f9-403b-b694-98cc427fa2f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc783629-94f9-403b-b694-98cc427fa2f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pixar_movies = pd.read_csv("pixar_films new.csv")
# Number of rows
print(pixar_movies.shape[0])
# Out:
# 28

# %%
# Number of columns
print(pixar_movies.shape[1])
# Out:
# 16

# %%
pixar_movies.head(10)
# Out:
#    ID             film film_rating cinema_score release_date  run_time  \
# 0   1        Toy Story           G            A   1995-11-22        81
# 1   2     A Bug's Life           G            A   1998-11-25        95
# 2   3      Toy Story 2           G           A+   1999-11-24        92
# 3   4   Monsters, Inc.           G           A+   2001-11-02        92
# 4   5     Finding Nemo           G           A+   2003-05-30       100
# 5   6  The Incredibles          PG           A+   2004-11-05       115
# 6   7             Cars           G            A   2006-06-09       116
# 7   8      Ratatouille           G            A   2007-06-29       111
# 8   9           WALL-E           G            A   2008-06-27        98
# 9  10               Up          PG           A+   2009-05-29        96
#
#       budget  box_office_us_canada  box_office_other  box_office_worldwide  \
# 0   30000000             223225679         171210907             394436586
# ...

# %%
pixar_movies.dtypes
# Out:
# ID                          int64
# film                       object
# film_rating                object
# cinema_score               object
# release_date               object
# run_time                    int64
# budget                      int64
# box_office_us_canada        int64
# box_office_other            int64
# box_office_worldwide        int64
# rotten_tomatoes_score       int64
# rotten_tomatoes_counts      int64
# metacritic_score            int64
# metacritic_counts           int64
# imdb_score                float64
# imdb_counts                 int64
# dtype: object

# %% [markdown]
# # Data Cleaning

# %%
# Multiply the `IMDB Score` column by 10
pixar_movies["imdb_score"] = pixar_movies["imdb_score"]*10

# %%
# Create a new DataFrame containing only the first 14 rows.
filtered_pixar = pixar_movies.loc[0:13]

# %%
# Set the `Movie` column as the index for the DataFrame.
pixar_movies.set_index("film", inplace=True)
filtered_pixar.set_index("film", inplace=True)

# %%
pixar_movies
# Out:
#                      ID film_rating cinema_score release_date  run_time  \
# film
# Toy Story             1           G            A   1995-11-22        81
# A Bug's Life          2           G            A   1998-11-25        95
# Toy Story 2           3           G           A+   1999-11-24        92
# Monsters, Inc.        4           G           A+   2001-11-02        92
# Finding Nemo          5           G           A+   2003-05-30       100
# The Incredibles       6          PG           A+   2004-11-05       115
# Cars                  7           G            A   2006-06-09       116
# Ratatouille           8           G            A   2007-06-29       111
# WALL-E                9           G            A   2008-06-27        98
# Up                   10          PG           A+   2009-05-29        96
# Toy Story 3          11           G            A   2010-06-18       103
# Cars 2               12           G           A-   2011-06-24       106
# ...

# %% [markdown]
# # Data Visualization, Line plots

# %%
critics_reviews = pixar_movies[["rotten_tomatoes_score","metacritic_score","imdb_score"]]
critics_reviews.plot()
# Out:
# <Axes: xlabel='film'>

# %%
critics_reviews.plot(figsize=(10,6))
# Out:
# <Axes: xlabel='film'>

# %% [markdown]
# # Data Visualization, Box plot

# %%
pixar_movies[["rotten_tomatoes_score","metacritic_score","imdb_score"]].plot(kind="box")
# Out:
# <Axes: >

# %%
pixar_movies[["rotten_tomatoes_score","metacritic_score","imdb_score"]].plot(kind="box", figsize=(9,5))
# Out:
# <Axes: >

# %% [markdown]
# # Data Visualization, Stacked Bar Plots

# %%
revenue_proportions = filtered_pixar[["box_office_us_canada", "box_office_worldwide"]]
revenue_proportions.plot(kind='bar', stacked=True, figsize=(7,6))
# Out:
# <Axes: xlabel='film'>

# %%
# Bar plot for IMDB Scores
filtered_pixar[["imdb_score"]].plot(kind='bar', figsize=(10,6))
# Out:
# <Axes: xlabel='film'>
